# %%
import pandas as pd
df = pd.read_csv('Pandas_learning/Pokemon.csv')
#df = pd.read_excel('')
#de = pd.read_csv('.txt',delimiter='\t')#delimiter是分隔符

# %%
print(df.head(2))
print(df.tail(2))
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65     45           1      False
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80     60           1      False
#        #                Name   Type 1 Type 2  Total  HP  ...  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 798  720  HoopaHoopa Unbound  Psychic   Dark    680  80  ...       60      170      130     80           6       True
# 799  721           Volcanion     Fire  Water    600  80  ...      120      130       90     70           6       True
#
# [2 rows x 13 columns]

# %%
#访问csv的特定一列
print(df['Name'])
print('-------------------------------------')
print(df[['HP','Speed']])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object
# -------------------------------------
#      HP  Speed
# 0    45     45
# 1    60     60
# 2    80     80
# 3    80     80
# 4    39     65
# ..   ..    ...
# 795  50     50
# 796  50    110
# 797  80     70
# 798  80     80
# 799  80     70
#
# [800 rows x 2 columns]

# %%
#访问csv的特定一行
print(df.iloc[0:2])
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65     45           1      False
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80     60           1      False

# %%
#遍历行
for index,row in df.iterrows():
    print(index,row)
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# Total             405
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# Total              525
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# ...

# %%
#访问csv的特定一个元素iloc(行，列)
print(df.iloc[0,4])
# Out:
# 318

# %%
#遍历行的特定元素
for index,row in df.iterrows():
    print(index,row['Type 2'])
# Out:
# 0 Poison
# 1 Poison
# 2 Poison
# 3 Poison
# 4 nan
# 5 nan
# 6 Flying
# 7 Dragon
# 8 Flying
# 9 nan
# 10 nan
# 11 nan
# 12 nan
# 13 nan
# 14 nan
# 15 Flying
# 16 Poison
# 17 Poison
# 18 Poison
# 19 Poison
# 20 Flying
# 21 Flying
# 22 Flying
# 23 Flying
# 24 nan
# 25 nan
# 26 Flying
# 27 Flying
# 28 nan
# 29 nan
# 30 nan
# 31 nan
# 32 nan
# 33 nan
# 34 nan
# 35 nan
# 36 Ground
# 37 nan
# 38 nan
# 39 Ground
# 40 nan
# 41 nan
# 42 nan
# 43 nan
# 44 Fairy
# 45 Fairy
# 46 Flying
# 47 Flying
# 48 Poison
# 49 Poison
# 50 Poison
# 51 Grass
# 52 Grass
# 53 Poison
# 54 Poison
# 55 nan
# 56 nan
# 57 nan
# 58 nan
# 59 nan
# 60 nan
# 61 nan
# 62 nan
# 63 nan
# 64 nan
# 65 nan
# 66 nan
# 67 Fighting
# 68 nan
# 69 nan
# 70 nan
# 71 nan
# 72 nan
# 73 nan
# 74 nan
# 75 Poison
# 76 Poison
# 77 Poison
# 78 Poison
# 79 Poison
# 80 Ground
# 81 Ground
# 82 Ground
# 83 nan
# 84 nan
# 85 Psychic
# 86 Psychic
# 87 Psychic
# 88 Steel
# 89 Steel
# 90 Flying
# 91 Flying
# 92 Flying
# 93 nan
# 94 Ice
# 95 nan
# ...

# %%
#寻找特定属性的个体
df.loc[df['Type 1']=='Fire']
# Out:
#        #                       Name Type 1    Type 2  Total  ...  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4      4                 Charmander   Fire       NaN    309  ...       60       50     65           1      False
# 5      5                 Charmeleon   Fire       NaN    405  ...       80       65     80           1      False
# 6      6                  Charizard   Fire    Flying    534  ...      109       85    100           1      False
# 7      6  CharizardMega Charizard X   Fire    Dragon    634  ...      130       85    100           1      False
# 8      6  CharizardMega Charizard Y   Fire    Flying    634  ...      159      115    100           1      False
# 42    37                     Vulpix   Fire       NaN    299  ...       50       65     65           1      False
# 43    38                  Ninetales   Fire       NaN    505  ...       81      100    100           1      False
# ...

# %%
#描述数据类型
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk     Sp. Def       Speed  Generation
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000   800.00000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000   71.902500   68.277500     3.32375
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294   27.828916   29.060474     1.66129
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000   20.000000    5.000000     1.00000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000   50.000000   45.000000     2.00000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000   70.000000   65.000000     3.00000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000   90.000000   90.000000     5.00000
# ...

# %%
#按规则排序csv
df.sort_values('Name')#这是正序a->z
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  ...  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 510  460                Abomasnow    Grass     Ice    494   90  ...       75       92       85     60           4      False
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90  ...      105      132      105     30           4      False
# 68    63                     Abra  Psychic     NaN    310   25  ...       15      105       55     90           1      False
# 392  359                    Absol     Dark     NaN    465   65  ...       60       75       60     75           3      False
# 393  359          AbsolMega Absol     Dark     NaN    565   65  ...       60      115       60    115           3      False
# ..   ...                      ...      ...     ...    ...  ...  ...      ...      ...      ...    ...         ...        ...
# ...

# %%
#按规则排序csv
df.sort_values('Name',ascending=False)#这是逆序z->a,ascending是上升的意思
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  ...  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108  ...      121       81       95     95           6       True
# 695  634                 Zweilous     Dark  Dragon    420   72  ...       70       65       70     58           5      False
# 46    41                    Zubat   Poison  Flying    245   40  ...       35       30       40     55           1      False
# 631  570                    Zorua     Dark     NaN    330   40  ...       40       80       40     65           5      False
# 632  571                  Zoroark     Dark     NaN    510   60  ...       60      120       60    105           5      False
# ..   ...                      ...      ...     ...    ...  ...  ...      ...      ...      ...    ...         ...        ...
# ...

# %%
#按多值规则排序csv
df.sort_values(['Type 1','HP'],ascending=[False,True])#这是逆序z->a,ascending是上升的意思
# Out:
#        #                     Name Type 1    Type 2  Total  HP  ...  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 139  129                 Magikarp  Water       NaN    200  20  ...       55       15       20     80           1      False
# 381  349                   Feebas  Water       NaN    200  20  ...       20       10       55     80           3      False
# 97    90                 Shellder  Water       NaN    305  30  ...      100       45       25     40           1      False
# 106   98                   Krabby  Water       NaN    325  30  ...       90       25       25     50           1      False
# 125  116                   Horsea  Water       NaN    295  30  ...       70       70       25     60           1      False
# ..   ...                      ...    ...       ...    ...  ..  ...      ...      ...      ...    ...         ...        ...
# ...

# %%
df['Total']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.drop(columns=['Total'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df['Total']=df.iloc[:,5:11].sum(axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.drop(columns=['Total'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df['Total']=df.iloc[:,5:11].sum(axis=1)
cols=list(df.columns)
cols
df=df[cols[0:4]+cols[5:12]+[cols[4]]]
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Total
# 0         65       65     45           1    318
# ...

# %%
df.drop(columns=['Total'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation
# 0         65       65     45           1
# 1         80       80     60           1
# ...

# %%
df['Total']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.to_csv('Pandas_learning/Pokemonv1.csv')

# %%
df.to_csv('Pandas_learning/Pokemonv2.csv',index=False)

# %%
df.to_excel('Pandas_learning/Pokemon.xlsx',index=False)

# %%
df.to_csv('Pandas_learning/Pokemon.txt',sep='\t',index=False)
